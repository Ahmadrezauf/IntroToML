# %%
import pandas as pd

dat1 = pd.read_csv("./Results/prediction.csv copy.zip")
print(dat1)

dat2 = pd.read_csv("./Results/prediction.csv.zip")
print(dat2)
# Out:
#            pid  LABEL_BaseExcess  LABEL_Fibrinogen  LABEL_AST  \
# 0          0.0             0.552             0.653      0.711
# 1          3.0             0.399             0.375      0.513
# 2          5.0             0.543             0.552      0.532
# 3          7.0             0.614             0.678      0.629
# 4          9.0             0.379             0.400      0.594
# ...        ...               ...               ...        ...
# 12659  31647.0             0.555             0.547      0.498
# 12660  31649.0             0.668             0.477      0.445
# 12661  31651.0             0.433             0.350      0.442
# 12662  31652.0             0.479             0.455      0.525
# 12663  31655.0             0.468             0.480      0.523
#
#        LABEL_Alkalinephos  LABEL_Bilirubin_total  LABEL_Lactate  \
# 0                   0.714                  0.711          0.569
# 1                   0.517                  0.511          0.427
# ...

# %%
dat3 = pd.concat([dat2.iloc[:,0:12], dat1.iloc[:,12:17]], axis = 1)
print(dat3.shape)
dat3.to_csv('./Results/merged.csv.zip', index=False, float_format='%.3f', compression='zip')
# Out:
# (12664, 16)

# %%
print(dat3)
# Out:
#            pid  LABEL_BaseExcess  LABEL_Fibrinogen  LABEL_AST  \
# 0          0.0             0.000             0.647      1.000
# 1          3.0             0.340             0.297      0.444
# 2          5.0             0.470             0.351      0.448
# 3          7.0             0.244             0.001      0.494
# 4          9.0             0.730             0.111      0.423
# ...        ...               ...               ...        ...
# 12659  31647.0             0.554             0.448      0.448
# 12660  31649.0             0.187             0.330      0.678
# 12661  31651.0             0.975             0.148      0.114
# 12662  31652.0             0.428             0.075      0.702
# 12663  31655.0             0.330             0.420      0.451
#
#        LABEL_Alkalinephos  LABEL_Bilirubin_total  LABEL_Lactate  \
# 0                   1.000                  1.000          0.392
# 1                   0.337                  0.413          0.500
# ...
